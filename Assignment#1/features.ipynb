# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a **Histogram of Oriented
# Gradients (HOG)** as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 30# Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7, 2e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
    for reg in regularization_strengths:
        svm = LinearSVM()
        svm_model = svm.train(X_train_feats, y_train, learning_rate = lr, reg =reg, num_iters = 1500)
        train_acc = np.mean(svm.predict(X_train_feats) == y_train)
        val_acc = np.mean(svm.predict(X_val_feats) == y_val)
        results[(lr, reg)] = (train_acc, val_acc)
        if val_acc > best_val:
            best_val = val_acc
            best_svm = svm
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.110082 val accuracy: 0.110000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.099204 val accuracy: 0.081000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.422143 val accuracy: 0.427000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.087429 val accuracy: 0.094000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.421735 val accuracy: 0.425000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.420776 val accuracy: 0.425000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.424673 val accuracy: 0.420000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.416755 val accuracy: 0.439000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.318735 val accuracy: 0.341000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.423265 val accuracy: 0.413000
# lr 2.000000e-07 reg 5.000000e+05 train accuracy: 0.400041 val accuracy: 0.399000
# lr 2.000000e-07 reg 5.000000e+06 train accuracy: 0.091000 val accuracy: 0.068000
# best validation accuracy achieved during cross-validation: 0.439000

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.416

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off') 
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$ For some mislabelled images, the color of the background and the subject are similar to that of the correct class.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 175)
# (49000, 174)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
#hidden_dim = 500
num_classes = 10

log = {}
net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None
best_acc = -1
################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
max_count = 100
for count in range(max_count):
    hidden_dim = int(np.random.uniform(80,90))
    lr = 10**np.random.uniform(-4,-6)
    reg = 10**np.random.uniform(-3,3)
    stats = net.train(X_train_feats, y_train, X_val_feats, y_val, learning_rate = lr, reg =reg, num_iters = 1500,batch_size=200,
            learning_rate_decay=0.95)
    val_acc = stats['val_acc_history'][-1]
    log[(lr, reg)] = val_acc
    print('learning rate = %1.1e, reg = %1.3f --> validation accuracy = %f, %d/100' 
      %(lr, reg, val_acc,count))
    if val_acc > best_acc:
        best_acc = val_acc
        best_net = net
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# learning rate = 2.3e-05, reg = 17.287 --> validation accuracy = 0.081000, 0/100
# learning rate = 3.5e-06, reg = 24.974 --> validation accuracy = 0.081000, 1/100
# learning rate = 3.9e-06, reg = 0.002 --> validation accuracy = 0.083000, 2/100
# learning rate = 3.5e-06, reg = 13.632 --> validation accuracy = 0.083000, 3/100
# learning rate = 5.4e-06, reg = 0.736 --> validation accuracy = 0.084000, 4/100
# learning rate = 5.1e-06, reg = 0.475 --> validation accuracy = 0.083000, 5/100
# learning rate = 4.2e-06, reg = 118.397 --> validation accuracy = 0.088000, 6/100
# learning rate = 2.5e-06, reg = 0.002 --> validation accuracy = 0.088000, 7/100
# learning rate = 1.5e-05, reg = 0.011 --> validation accuracy = 0.095000, 8/100
# learning rate = 4.4e-06, reg = 0.006 --> validation accuracy = 0.097000, 9/100
# learning rate = 5.4e-06, reg = 2.116 --> validation accuracy = 0.099000, 10/100
# learning rate = 8.0e-06, reg = 0.020 --> validation accuracy = 0.101000, 11/100
# learning rate = 1.2e-06, reg = 0.004 --> validation accuracy = 0.102000, 12/100
# learning rate = 3.6e-06, reg = 0.009 --> validation accuracy = 0.104000, 13/100
# learning rate = 5.3e-05, reg = 84.980 --> validation accuracy = 0.120000, 14/100
# learning rate = 5.4e-06, reg = 0.031 --> validation accuracy = 0.123000, 15/100
# learning rate = 1.0e-05, reg = 0.218 --> validation accuracy = 0.126000, 16/100
# learning rate = 3.9e-06, reg = 0.006 --> validation accuracy = 0.126000, 17/100
# learning rate = 2.6e-06, reg = 1.486 --> validation accuracy = 0.127000, 18/100
# learning rate = 1.4e-05, reg = 17.701 --> validation accuracy = 0.129000, 19/100
# learning rate = 1.5e-06, reg = 108.173 --> validation accuracy = 0.129000, 20/100
# learning rate = 3.3e-05, reg = 1.753 --> validation accuracy = 0.136000, 21/100
# learning rate = 1.3e-06, reg = 1.340 --> validation accuracy = 0.136000, 22/100
# learning rate = 1.2e-06, reg = 0.012 --> validation accuracy = 0.136000, 23/100
# learning rate = 2.6e-06, reg = 11.433 --> validation accuracy = 0.137000, 24/100
# learning rate = 3.9e-05, reg = 43.092 --> validation accuracy = 0.151000, 25/100
# learning rate = 6.4e-06, reg = 0.209 --> validation accuracy = 0.152000, 26/100
# learning rate = 2.7e-05, reg = 21.613 --> validation accuracy = 0.158000, 27/100
# learning rate = 1.8e-05, reg = 37.742 --> validation accuracy = 0.162000, 28/100
# learning rate = 9.8e-06, reg = 0.017 --> validation accuracy = 0.164000, 29/100
# learning rate = 3.2e-05, reg = 3.385 --> validation accuracy = 0.169000, 30/100
# learning rate = 6.1e-06, reg = 0.015 --> validation accuracy = 0.172000, 31/100
# learning rate = 9.6e-05, reg = 43.786 --> validation accuracy = 0.194000, 32/100
# learning rate = 6.5e-06, reg = 0.022 --> validation accuracy = 0.194000, 33/100
# learning rate = 6.8e-06, reg = 0.002 --> validation accuracy = 0.195000, 34/100
# learning rate = 4.5e-06, reg = 0.006 --> validation accuracy = 0.196000, 35/100
# learning rate = 7.2e-06, reg = 0.069 --> validation accuracy = 0.197000, 36/100
# learning rate = 7.9e-06, reg = 0.003 --> validation accuracy = 0.199000, 37/100
# learning rate = 2.6e-05, reg = 0.001 --> validation accuracy = 0.200000, 38/100
# learning rate = 9.9e-05, reg = 0.277 --> validation accuracy = 0.221000, 39/100
# learning rate = 8.0e-05, reg = 0.153 --> validation accuracy = 0.237000, 40/100
# learning rate = 5.5e-05, reg = 0.001 --> validation accuracy = 0.245000, 41/100
# learning rate = 1.2e-06, reg = 4.838 --> validation accuracy = 0.244000, 42/100
# learning rate = 1.2e-05, reg = 9.341 --> validation accuracy = 0.244000, 43/100
# learning rate = 1.6e-06, reg = 50.168 --> validation accuracy = 0.244000, 44/100
# learning rate = 3.4e-05, reg = 31.472 --> validation accuracy = 0.251000, 45/100
# learning rate = 2.3e-05, reg = 15.524 --> validation accuracy = 0.255000, 46/100
# learning rate = 4.3e-05, reg = 180.450 --> validation accuracy = 0.261000, 47/100
# learning rate = 6.1e-06, reg = 644.390 --> validation accuracy = 0.261000, 48/100
# learning rate = 8.7e-05, reg = 206.562 --> validation accuracy = 0.271000, 49/100
# learning rate = 2.5e-05, reg = 0.320 --> validation accuracy = 0.274000, 50/100
# learning rate = 2.6e-06, reg = 0.060 --> validation accuracy = 0.274000, 51/100
# learning rate = 4.7e-06, reg = 39.518 --> validation accuracy = 0.274000, 52/100
# learning rate = 1.2e-06, reg = 149.113 --> validation accuracy = 0.273000, 53/100
# learning rate = 2.9e-06, reg = 314.549 --> validation accuracy = 0.273000, 54/100
# learning rate = 2.6e-06, reg = 17.689 --> validation accuracy = 0.274000, 55/100
# learning rate = 4.2e-05, reg = 0.397 --> validation accuracy = 0.281000, 56/100
# learning rate = 1.7e-05, reg = 231.939 --> validation accuracy = 0.284000, 57/100
# learning rate = 3.6e-05, reg = 824.453 --> validation accuracy = 0.291000, 58/100
# learning rate = 1.4e-05, reg = 0.302 --> validation accuracy = 0.289000, 59/100
# learning rate = 1.7e-05, reg = 0.019 --> validation accuracy = 0.291000, 60/100
# learning rate = 2.7e-05, reg = 0.540 --> validation accuracy = 0.292000, 61/100
# learning rate = 3.6e-06, reg = 615.549 --> validation accuracy = 0.292000, 62/100
# learning rate = 4.3e-06, reg = 0.030 --> validation accuracy = 0.294000, 63/100
# learning rate = 5.3e-05, reg = 21.490 --> validation accuracy = 0.296000, 64/100
# learning rate = 1.1e-05, reg = 0.127 --> validation accuracy = 0.296000, 65/100
# learning rate = 1.1e-05, reg = 0.009 --> validation accuracy = 0.295000, 66/100
# learning rate = 1.5e-06, reg = 0.003 --> validation accuracy = 0.295000, 67/100
# learning rate = 1.2e-06, reg = 156.715 --> validation accuracy = 0.295000, 68/100
# learning rate = 8.9e-05, reg = 59.715 --> validation accuracy = 0.305000, 69/100
# learning rate = 5.5e-06, reg = 10.714 --> validation accuracy = 0.306000, 70/100
# learning rate = 2.5e-05, reg = 54.773 --> validation accuracy = 0.306000, 71/100
# learning rate = 1.4e-05, reg = 68.463 --> validation accuracy = 0.308000, 72/100
# learning rate = 2.2e-06, reg = 29.605 --> validation accuracy = 0.309000, 73/100
# learning rate = 1.5e-05, reg = 0.021 --> validation accuracy = 0.308000, 74/100
# learning rate = 1.3e-05, reg = 0.003 --> validation accuracy = 0.308000, 75/100
# learning rate = 3.9e-05, reg = 0.017 --> validation accuracy = 0.311000, 76/100
# learning rate = 4.5e-05, reg = 28.479 --> validation accuracy = 0.315000, 77/100
# learning rate = 7.3e-05, reg = 70.187 --> validation accuracy = 0.318000, 78/100
# learning rate = 5.5e-05, reg = 8.033 --> validation accuracy = 0.322000, 79/100
# learning rate = 1.6e-05, reg = 0.011 --> validation accuracy = 0.322000, 80/100
# learning rate = 1.3e-05, reg = 55.211 --> validation accuracy = 0.323000, 81/100
# learning rate = 4.4e-06, reg = 25.413 --> validation accuracy = 0.324000, 82/100
# learning rate = 8.5e-05, reg = 41.844 --> validation accuracy = 0.331000, 83/100
# learning rate = 3.8e-05, reg = 2.492 --> validation accuracy = 0.331000, 84/100
# learning rate = 1.5e-06, reg = 432.892 --> validation accuracy = 0.331000, 85/100
# learning rate = 1.3e-05, reg = 0.059 --> validation accuracy = 0.329000, 86/100
# learning rate = 1.0e-05, reg = 0.006 --> validation accuracy = 0.328000, 87/100
# learning rate = 2.4e-05, reg = 0.012 --> validation accuracy = 0.330000, 88/100
# learning rate = 1.0e-06, reg = 138.326 --> validation accuracy = 0.331000, 89/100
# learning rate = 4.2e-05, reg = 0.171 --> validation accuracy = 0.332000, 90/100
# learning rate = 1.0e-05, reg = 398.289 --> validation accuracy = 0.331000, 91/100
# learning rate = 1.0e-06, reg = 50.800 --> validation accuracy = 0.331000, 92/100
# learning rate = 1.4e-06, reg = 23.088 --> validation accuracy = 0.330000, 93/100
# learning rate = 3.6e-05, reg = 184.822 --> validation accuracy = 0.329000, 94/100
# learning rate = 9.8e-05, reg = 31.667 --> validation accuracy = 0.333000, 95/100
# learning rate = 3.8e-06, reg = 0.708 --> validation accuracy = 0.333000, 96/100
# learning rate = 7.4e-05, reg = 5.483 --> validation accuracy = 0.331000, 97/100
# learning rate = 9.7e-05, reg = 0.231 --> validation accuracy = 0.331000, 98/100
# learning rate = 4.6e-05, reg = 4.808 --> validation accuracy = 0.330000, 99/100

# %%
# Print out results.
for lr, reg in sorted(log):
    val_accuracy = log[(lr, reg)]
    print('lr %e reg %e val accuracy: %f' % (
                lr, reg,val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1
# lr 8.252955e-05 reg 5.173986e-02 val accuracy: 0.262000
# lr 9.267084e-05 reg 7.477338e+02 val accuracy: 0.087000
# lr 1.104011e-04 reg 1.732995e-02 val accuracy: 0.256000
# lr 1.170095e-04 reg 1.742055e-02 val accuracy: 0.256000
# lr 1.198821e-04 reg 1.343847e-03 val accuracy: 0.257000
# lr 1.332888e-04 reg 1.667907e+02 val accuracy: 0.087000
# lr 1.574634e-04 reg 1.749763e-03 val accuracy: 0.087000
# lr 1.619831e-04 reg 2.773320e+00 val accuracy: 0.087000
# lr 1.634587e-04 reg 2.444871e+00 val accuracy: 0.087000
# lr 1.737789e-04 reg 4.288959e+00 val accuracy: 0.343000
# lr 1.833486e-04 reg 3.723048e-01 val accuracy: 0.265000
# lr 1.833566e-04 reg 3.782341e-01 val accuracy: 0.087000
# lr 1.943639e-04 reg 6.730505e+02 val accuracy: 0.087000
# lr 2.016328e-04 reg 5.849731e-02 val accuracy: 0.087000
# lr 2.019349e-04 reg 4.929621e+00 val accuracy: 0.348000
# lr 2.186255e-04 reg 2.169004e-01 val accuracy: 0.361000
# lr 2.328259e-04 reg 3.516928e-02 val accuracy: 0.377000
# lr 2.340066e-04 reg 1.310360e-03 val accuracy: 0.357000
# lr 2.605538e-04 reg 2.500960e+00 val accuracy: 0.087000
# lr 2.804819e-04 reg 1.932523e+01 val accuracy: 0.087000
# lr 3.198825e-04 reg 1.686804e+01 val accuracy: 0.087000
# lr 3.385144e-04 reg 6.729833e+00 val accuracy: 0.087000
# lr 3.451392e-04 reg 1.309772e+00 val accuracy: 0.367000
# lr 3.495881e-04 reg 1.301720e+00 val accuracy: 0.170000
# lr 3.609713e-04 reg 2.761143e-03 val accuracy: 0.243000
# lr 3.677612e-04 reg 8.665128e-01 val accuracy: 0.087000
# lr 3.696052e-04 reg 3.671929e+00 val accuracy: 0.087000
# lr 3.918519e-04 reg 1.307876e-02 val accuracy: 0.283000
# lr 4.376002e-04 reg 1.395350e+01 val accuracy: 0.087000
# lr 4.668925e-04 reg 1.950695e+00 val accuracy: 0.258000
# lr 4.940426e-04 reg 9.290022e+00 val accuracy: 0.087000
# lr 5.093018e-04 reg 3.100704e-03 val accuracy: 0.243000
# lr 5.356175e-04 reg 6.691814e+02 val accuracy: 0.087000
# lr 5.420127e-04 reg 2.872166e-03 val accuracy: 0.087000
# lr 6.129472e-04 reg 8.427943e+01 val accuracy: 0.294000
# lr 6.189580e-04 reg 1.046095e+00 val accuracy: 0.087000
# lr 6.878842e-04 reg 3.716371e-03 val accuracy: 0.269000
# lr 7.031787e-04 reg 5.583107e-01 val accuracy: 0.317000
# lr 7.701705e-04 reg 2.281788e-02 val accuracy: 0.087000
# lr 7.952312e-04 reg 1.673076e-02 val accuracy: 0.244000
# lr 7.989088e-04 reg 3.510185e-03 val accuracy: 0.347000
# lr 8.536061e-04 reg 3.880838e+01 val accuracy: 0.087000
# lr 9.168364e-04 reg 1.489250e-03 val accuracy: 0.087000
# lr 9.744084e-04 reg 3.520674e+01 val accuracy: 0.087000
# lr 9.919197e-04 reg 2.039793e-01 val accuracy: 0.366000
# lr 9.963008e-04 reg 4.309818e+01 val accuracy: 0.341000
# lr 9.970506e-04 reg 2.046286e-02 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.439000

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.103
